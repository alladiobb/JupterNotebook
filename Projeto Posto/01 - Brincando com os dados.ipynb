# %%
import pandas as pd

caminho = r'ca.csv'

df = pd.read_csv(caminho, sep=';')
df.head(2)
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio                   Revenda  \
# 0             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 1             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
#
#        CNPJ da Revenda               Nome da Rua Numero Rua  \
# 0   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 1   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
#
#            Complemento      Bairro        Cep   Produto Data da Coleta  \
# 0  KM 210,5-SENT SP/RJ  BONSUCESSO  07178-580  GASOLINA     11/05/2004
# 1  KM 210,5-SENT SP/RJ  BONSUCESSO  07178-580    ETANOL     11/05/2004
#
#   Valor de Venda Valor de Compra Unidade de Medida  \
# 0          1,967          1,6623        R$ / litro
# 1          0,899          0,6282        R$ / litro
#
#                        Bandeira
# 0  PETROBRAS DISTRIBUIDORA S.A.
# 1  PETROBRAS DISTRIBUIDORA S.A.

# %%
df = df.sort_index(axis=1,ascending=False)
df.sort_values(by=['Valor de Compra','Valor de Venda'])
# Out:
#        Valor de Venda Valor de Compra Unidade de Medida  \
# 46736           0,789          0,3257        R$ / litro
# 11056            0,83           0,326        R$ / litro
# 126194          0,799          0,3398        R$ / litro
# 46570           0,899          0,3453        R$ / litro
# 117090          0,899          0,3453        R$ / litro
# ...               ...             ...               ...
# 246736           2,85             NaN        R$ / litro
# 234250           2,87             NaN        R$ / litro
# 269424           2,88             NaN        R$ / litro
# 234256           2,89             NaN        R$ / litro
# 234259           2,89             NaN        R$ / litro
#
#                                                   Revenda Regiao - Sigla  \
# 46736               POSTO DE GASOLINA NOVA ESPERANCA LTDA             SE
# 11056                       POSTO DE GASOLINA CARECA LTDA             SE
# ...
